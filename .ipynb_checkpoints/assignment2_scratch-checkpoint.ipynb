# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats.stats as stats
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %matplotlib inline
plt.rcParams.update({'xtick.direction': 'out', 'axes.spines.top': False, 'axes.spines.right': False})

df1 = pd.read_csv('dataverse_files/main_data.tab', sep="\t")
df1 = df1.dropna(axis=0, subset='time')
df1.filter(regex='\w*simple\w*')
# Out:
#         matched_simple
# 59                 NaN
# 60                 NaN
# 61                 NaN
# 62                 NaN
# 63                 NaN
# ...                ...
# 133635             NaN
# 133636             NaN
# 133637             NaN
# 133638             NaN
# 133639             NaN
#
# [58383 rows x 1 columns]

# %%
from IPython.display import display, HTML

s1_3_1 = df1[[ 'repression', 'lnrepression', 'dumrepression', 'hostcity', 'prox_hotelonly', 'prox_hotelpress', 
    'time', 'time2', 'time3', 'lnpop_1970', 'literacy_avg', 'vote_frejuli', 'lnrebact1974',  
    'lnrepression70_77', 'latitude', 'lnstrikes', 'lnlag_strikes', 'lnlag2_strikes', 
    'zone1', 'zone2', 'zone3', 'zone4', 'zone5']]


s1_3_1 = s1_3_1.rename(
    columns={
        'repression': '$Repression \ Events$',
        'lnrepression': '$Repression \ Events^a$',
        'dumrepression': '$Repression \ Events$',
        'hostcity': '$Host \ City$',
        'prox_hotelonly': '$Proximity \ to \ Hotel$',
        'prox_hotelpress': '$Proximity \ to \ Journalist \ Venue$',
        'time': '$Time$',
        'time2': '$Time^2$',
        'time3': '$Time^3$',
        'lnpop_1970': '$Population \ Size^a$',
        'literacy_avg': '$Literacy \ Rate$',
        'vote_frejuli': '$Peronist \ Vote \ Share$',
        'lnrebact1974': '$Rebel \ Activity^a$',
        'lnrepression70_77': '$Past \ Repression^a$',
        'latitude': '$Latitude$',
        'lnstrikes': '$Protest_{Current \ month}^a$',
        'lnlag_strikes': '$Protest_{One \ Month \ ago}^a$',
        'lnlag2_strikes': '$Protest_{Two \ Months \ ago}^a$',
        'zone1': '$Military \ Zone \ 1$',
        'zone2': '$Military \ Zone \ 2$',
        'zone3': '$Military \ Zone \ 3$',
        'zone4': '$Military \ Zone \ 4$',
        'zone5': '$Military \ Zone \ 5$',
        
    }
)

s1_3_1 = s1_3_1.describe().T.drop(columns=['25%', '50%', '75%'], errors='ignore')
s1_3_1 = s1_3_1.astype({
    'count': 'int',
})
for col in ['mean', 'std', 'min', 'max']:
    s1_3_1[col] = s1_3_1[col].map('{:,.3f}'.format)

s1_3_1 = s1_3_1.rename(columns={
    'count': 'Obs.',
    'mean': 'Mean',
    'std': 'Std. dev.',
    'min': 'Min.',
    'max': 'Max.'
})

types = [
    'Count', 'Continuous', 'Binary', 'Binary', 'Continuous', 'Continuous',
    'Count', 'Count', 'Count', 'Continuous', 'Continuous', 'Continuous',
    'Continuous', 'Continuous', 'Continuous', 'Continuous', 'Continuous',
    'Continuous', 'Binary', 'Binary', 'Binary', 'Binary', 'Binary',
]

s1_3_1.insert(0, 'Type', types)
display(HTML(s1_3_1.to_html()+"<p>Hello$^a$</p>"))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Type</th>
#       <th>Obs.</th>
#       <th>Mean</th>
#       <th>Std. dev.</th>
#       <th>Min.</th>
#       <th>Max.</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$Repression \ Events$</th>
#       <td>Count</td>
#       <td>58107</td>
#       <td>0.005</td>
#       <td>0.104</td>
#       <td>0.000</td>
#       <td>7.000</td>
#     </tr>
#     <tr>
#       <th>$Repression \ Events^a$</th>
#       <td>Continuous</td>
#       <td>58107</td>
#       <td>0.003</td>
#       <td>0.053</td>
#       <td>0.000</td>
#       <td>2.079</td>
#     </tr>
#     <tr>
#       <th>$Repression \ Events$</th>
#       <td>Binary</td>
#       <td>58107</td>
#       <td>0.003</td>
#       <td>0.058</td>
#       <td>0.000</td>
#       <td>1.000</td>
#     </tr>
#     <tr>
#       <th>$Host \ City$</th>
#       <td>Binary</td>
#       <td>58383</td>
# ...

# %%
print((s1_3_1.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Type</th>
#       <th>Obs.</th>
#       <th>Mean</th>
#       <th>Std. dev.</th>
#       <th>Min.</th>
#       <th>Max.</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$Repression \ Events$</th>
#       <td>Count</td>
#       <td>58107</td>
#       <td>0.005</td>
#       <td>0.104</td>
#       <td>0.000</td>
#       <td>7.000</td>
#     </tr>
#     <tr>
#       <th>$Repression \ Events^a$</th>
#       <td>Continuous</td>
#       <td>58107</td>
#       <td>0.003</td>
#       <td>0.053</td>
#       <td>0.000</td>
#       <td>2.079</td>
#     </tr>
#     <tr>
#       <th>$Repression \ Events$</th>
#       <td>Binary</td>
#       <td>58107</td>
#       <td>0.003</td>
#       <td>0.058</td>
#       <td>0.000</td>
#       <td>1.000</td>
#     </tr>
#     <tr>
#       <th>$Host \ City$</th>
#       <td>Binary</td>
#       <td>58383</td>
# ...

# %%
df2 = pd.read_csv('dataverse_files/figure_1_data.tab', sep="\t")
df2
# Out:
#    postcwy  event_selec  autochost  autochostperc
# 0      1.0         25.0        2.0       8.000000
# 1      2.0         31.0        4.0      12.903226
# 2      3.0         25.0        5.0      20.000000
# 3      4.0         24.0        6.0      25.000000
# 4      5.0         30.0        6.0      20.000000
# 5      6.0         32.0        9.0      28.125000
# 6      7.0         27.0       10.0      37.037037

# %%
df2.insert(0, 'Years', ['1990-1994', '1995-1999', '2000-2004', '2005-2009', '2010-2014', '2014-2019', '2020-2024'])

# %%
fig, ax = plt.subplots()


plt.xticks(rotation=45)


plt.xlim((0, 6))
plt.ylim(0, 50)

plt.xlabel('Years', fontsize=12) 
plt.ylabel('Autocratic host regimes (in %)', fontsize=11)

plt.title('Figure 1.    Autocratic Hosts of International\n Sports Events, 1990–2024', fontsize=20, loc='left',\
         fontweight="bold")
plt.figtext(0.0, -0.4, \
"Note: Graph shows the five-year shares of autocratic states\n\
among all hosting nations of the world championships in athletics,\n\
basketball, cricket, football, handball, ice hockey, rugby, table \n\
tennis, and volleyball, as well as the Summer and Winter\n\
Olympics. See Figure SI.1.1 for a breakdown of all tournaments\n\
and hosts since 1945.", ha="left", fontsize=12, bbox={"facecolor":"white", "pad":5})

# plt.rcParams.update({'xtick.direction': 'out', 'axes.spines.top': False, 'axes.spines.right': False})

ax.plot( df2['Years'], df2['autochostperc'], marker='o', c='black')
ax.spines['left'].set_position(('outward', 20))

# %%
df3 = pd.read_csv('dataverse_files/figure_SI11_data.tab', sep="\t")
df3
# Out:
#        year  regime  baseline  democ  autoc
# 0    1987.0     0.0       2.5    3.0    NaN
# 1    1987.0     0.0       2.5    3.0    NaN
# 2    1991.0     0.0       2.5    3.0    NaN
# 3    1991.0     0.0       2.5    3.0    NaN
# 4    1995.0     1.0       2.5    NaN    2.0
# ..      ...     ...       ...    ...    ...
# 328  2010.0     0.0      27.5   28.0    NaN
# 329  2014.0     0.0      27.5   28.0    NaN
# 330  2018.0     0.0      27.5   28.0    NaN
# 331  2018.0     0.0      27.5   28.0    NaN
# 332  2022.0     1.0      27.5    NaN   27.0
#
# [333 rows x 5 columns]

# %%
df3 = df3.fillna(0)
df3
# Out:
#        year  regime  baseline  democ  autoc
# 0    1987.0     0.0       2.5    3.0    0.0
# 1    1987.0     0.0       2.5    3.0    0.0
# 2    1991.0     0.0       2.5    3.0    0.0
# 3    1991.0     0.0       2.5    3.0    0.0
# 4    1995.0     1.0       2.5    0.0    2.0
# ..      ...     ...       ...    ...    ...
# 328  2010.0     0.0      27.5   28.0    0.0
# 329  2014.0     0.0      27.5   28.0    0.0
# 330  2018.0     0.0      27.5   28.0    0.0
# 331  2018.0     0.0      27.5   28.0    0.0
# 332  2022.0     1.0      27.5    0.0   27.0
#
# [333 rows x 5 columns]

# %%
df3['DA'] = np.where(df3['democ'] != 0.0, df3['democ'], df3['autoc'])
df3 = df3.loc[df3['DA'] != 0.0]
df3
# Out:
#        year  regime  baseline  democ  autoc    DA
# 0    1987.0     0.0       2.5    3.0    0.0   3.0
# 1    1987.0     0.0       2.5    3.0    0.0   3.0
# 2    1991.0     0.0       2.5    3.0    0.0   3.0
# 3    1991.0     0.0       2.5    3.0    0.0   3.0
# 4    1995.0     1.0       2.5    0.0    2.0   2.0
# ..      ...     ...       ...    ...    ...   ...
# 328  2010.0     0.0      27.5   28.0    0.0  28.0
# 329  2014.0     0.0      27.5   28.0    0.0  28.0
# 330  2018.0     0.0      27.5   28.0    0.0  28.0
# 331  2018.0     0.0      27.5   28.0    0.0  28.0
# 332  2022.0     1.0      27.5    0.0   27.0  27.0
#
# [332 rows x 6 columns]

# %%
champs = {
    27.5: 'Volleyball World Championship', 
    25.0: 'Basketball World Cup', 
    22.5: 'World Table Tennis Championship',
    20.0: 'World Handball Championship',
    17.5: 'Cricket World Championship',
    15.0: 'FIFA World Cup',
    12.5: 'Ice Hockey World Championships',
    10.0: 'World Athletic Championships',
    7.5 : 'Summer Olympic Games',
    5.0 : 'Winter Olympic Games',
    2.5 : 'Rugby World Cup'
}
df3['champs'] = df3['baseline'].map(champs)
df3
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_40512\2450324257.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['champs'] = df3['baseline'].map(champs)
#        year  regime  baseline  democ  autoc    DA  \
# 0    1987.0     0.0       2.5    3.0    0.0   3.0
# 1    1987.0     0.0       2.5    3.0    0.0   3.0
# 2    1991.0     0.0       2.5    3.0    0.0   3.0
# 3    1991.0     0.0       2.5    3.0    0.0   3.0
# 4    1995.0     1.0       2.5    0.0    2.0   2.0
# ..      ...     ...       ...    ...    ...   ...
# 328  2010.0     0.0      27.5   28.0    0.0  28.0
# 329  2014.0     0.0      27.5   28.0    0.0  28.0
# 330  2018.0     0.0      27.5   28.0    0.0  28.0
# 331  2018.0     0.0      27.5   28.0    0.0  28.0
# ...

# %%
# Disable top and right spine
plt.rcParams.update({'axes.spines.top': False, 'axes.spines.right': False, 'axes.xmargin': 0.0})

# %%
ax = sns.scatterplot(data=df3, x='year', y='DA', marker='s', hue='regime', palette=['#808080', '#000000'], \
                 s=40, legend=False)

for y in set(df3['baseline'].values):
    ax.axhline(y, c='#808080', alpha=0.3)


ax.spines['left'].set_position(('outward', 20))  

plt.title(r'$\bf{Figure \ SI.1.1.}$' +  'Host regimes of international sports event, 1945-2024', loc='left')

plt.figtext(-0.3, -0.1, \
"Note: Black spikes indicate autocratic host regimes, grey spikes indicate democratic host\n\
regimes." , ha="left", fontsize=12)

# Remove Labels
plt.ylabel('')
plt.xlabel('')

plt.xlim()

plt.xticks([tick for tick in range(1950, 2024, 10)])
plt.yticks(df3['baseline'], labels=df3['champs'])

plt.ylim((df3.DA.min() - 1, df3.DA.max() + 1))
# Out:
# (1.0, 29.0)

# %%
df3 = pd.read_csv('dataverse_files/main_data.tab', sep="\t")
df3
# Out:
#                  muni     id          prov  id_prov  \
# 0       adolfo alsina    1.0  buenos aires      1.0
# 1       adolfo alsina    1.0  buenos aires      1.0
# 2       adolfo alsina    1.0  buenos aires      1.0
# 3       adolfo alsina    1.0  buenos aires      1.0
# 4       adolfo alsina    1.0  buenos aires      1.0
# ...               ...    ...           ...      ...
# 133727    yerba buena  499.0       tucuman     24.0
# 133728    yerba buena  499.0       tucuman     24.0
# 133729    yerba buena  499.0       tucuman     24.0
# 133730    yerba buena  499.0       tucuman     24.0
# 133731    yerba buena  499.0       tucuman     24.0
#
#                           muniprov  repression  lnrepression  dumrepression  \
# 0       adolfo alsina buenos aires         0.0           0.0            0.0
# 1       adolfo alsina buenos aires         0.0           0.0            0.0
# 2       adolfo alsina buenos aires         0.0           0.0            0.0
# ...

# %%
no_host = df3.loc[df3['hostcity'] != 1.0]
host = df3.loc[df3['hostcity'] == 1.0]
no_host
# Out:
#                  muni     id          prov  id_prov  \
# 0       adolfo alsina    1.0  buenos aires      1.0
# 1       adolfo alsina    1.0  buenos aires      1.0
# 2       adolfo alsina    1.0  buenos aires      1.0
# 3       adolfo alsina    1.0  buenos aires      1.0
# 4       adolfo alsina    1.0  buenos aires      1.0
# ...               ...    ...           ...      ...
# 133727    yerba buena  499.0       tucuman     24.0
# 133728    yerba buena  499.0       tucuman     24.0
# 133729    yerba buena  499.0       tucuman     24.0
# 133730    yerba buena  499.0       tucuman     24.0
# 133731    yerba buena  499.0       tucuman     24.0
#
#                           muniprov  repression  lnrepression  dumrepression  \
# 0       adolfo alsina buenos aires         0.0           0.0            0.0
# 1       adolfo alsina buenos aires         0.0           0.0            0.0
# 2       adolfo alsina buenos aires         0.0           0.0            0.0
# ...

# %%
host.groupby(by='muni').sum()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_40512\3592064134.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   host.groupby(by='muni').sum()
#                           id  id_prov  repression  lnrepression  \
# muni
# capital             132660.0   5092.0        24.0     15.079339
# capital federal      33500.0    536.0       218.0    114.326369
# general pueyrredon   11792.0    268.0        34.0     17.094242
# rosario             119528.0   5628.0        12.0      6.579251
#
#                     dumrepression  hostcity  hostcitynum  prewc_time3m  \
# muni
# capital                      19.0     536.0       2412.0       13806.0
# capital federal             119.0     268.0        268.0        6903.0
# general pueyrredon           16.0     268.0        536.0        6903.0
# ...

# %%
no_host.groupby(by='muni').sum()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_40512\514111439.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   no_host.groupby(by='muni').sum()
#                      id  id_prov  repression  lnrepression  dumrepression  \
# muni
# 25 de mayo      97552.0   4288.0         1.0      0.693147            1.0
# 25deMayo       195908.0   8576.0         0.0      0.000000            0.0
# 9de,Julio       97820.0   4288.0         0.0      0.000000            0.0
# 9deJulio       224048.0  10452.0         0.0      0.000000            0.0
# Adolfo Alsina   98088.0   4288.0         0.0      0.000000            0.0
# ...                 ...      ...         ...           ...            ...
# yavi            72896.0   2680.0         0.0      0.000000            0.0
# ...

# %%
model1 = smf.ols('lnrepression ~ hostcity + hostcitytime + hostcitytime2 + time + time2 ', data=df3)
reg_res1 = model1.fit()

model2 = smf.ols('lnrepression ~ hostcity + hostcitytime + hostcitytime2 + time + time2 + lnpop_1970 +\
            vote_frejuli + literacy_avg + lnrebact1974 + lnrepression70_77', data=df3)
reg_res2 = model2.fit()

model3 = smf.ols('lnrepression ~ hostcitytime + hostcitytime2  + lnpop_1970 + vote_frejuli +\
                 literacy_avg + lnrebact1974 + lnrepression70_77+ zone2 + zone3 +\
            zone4 + zone5', data=df3)
reg_res3 = model3.fit()

print("Regression results for model 1")
print("===============================")
print(reg_res1.params)
print("===============================")
print("Regression results for model 2")
print("===============================")
print(reg_res2.params)
print("===============================")
print("Regression results for model 3")
print("===============================")
print(reg_res3.params)
# Out:
# Regression results for model 1
# ...
# Intercept        0.002569
# hostcity         0.020187
# hostcitytime     0.401240
# hostcitytime2   -0.322958
# time            -0.002841
# time2            0.002021
# dtype: float64
# ...
# Regression results for model 2
# ...
# Intercept           -0.004077
# hostcity            -0.003689
# hostcitytime         0.401445
# hostcitytime2       -0.323106
# time                -0.003046
# time2                0.002169
# lnpop_1970           0.000970
# vote_frejuli        -0.000032
# literacy_avg        -0.005559
# lnrebact1974        -0.000121
# lnrepression70_77    0.004079
# dtype: float64
# ...
# Regression results for model 3
# ...
# Intercept           -0.004745
# hostcitytime         0.387657
# hostcitytime2       -0.313319
# lnpop_1970           0.003261
# vote_frejuli         0.000011
# literacy_avg        -0.023103
# lnrebact1974        -0.001393
# lnrepression70_77    0.003150
# zone2               -0.014671
# zone3               -0.011694
# ...

# %%
reg_res3.rsquared
# Out:
# 0.06318659005878802

# %%
reg_res1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           lnrepression   R-squared:                       0.046
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     554.0
# Date:                Mon, 05 Dec 2022   Prob (F-statistic):               0.00
# Time:                        19:50:03   Log-Likelihood:                 89824.
# No. Observations:               58107   AIC:                        -1.796e+05
# Df Residuals:                   58101   BIC:                        -1.796e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
figure = plt.figure(figsize=(10, 20))
figure.subplots_adjust(hspace=0.4)

vals = np.linspace(0, 2, 100)

ypos1 = list()
yneg1 = list()

ypos2 = list()
yneg2 = list()

ypos3 = list()
yneg3 = list()

for x in vals:
    ypos1.append(x * reg_res1.params['hostcitytime'])
    yneg1.append(x * reg_res1.params['hostcitytime2'])
    
    ypos2.append(x * reg_res2.params['hostcitytime'])
    yneg2.append(x * reg_res2.params['hostcitytime2'])
    
    ypos3.append(x * reg_res3.params['hostcitytime'])
    yneg3.append(x * reg_res3.params['hostcitytime2'])
    
ax = figure.add_subplot(3, 2, 1)
ax.set_xlabel('Reg Res 1 hostcitytime')
ax.set_ylabel('vals')
ax.plot(ypos1)
ax = figure.add_subplot(3, 2, 2)
ax.set_xlabel('Reg Res 1 hostcitytime2')
ax.set_ylabel('vals')
ax.plot(yneg1)
ax = figure.add_subplot(3, 2, 3)
ax.set_xlabel('Reg Res 2 hostcitytime')
ax.set_ylabel('vals')
ax.plot(ypos2)
ax = figure.add_subplot(3, 2, 4)
ax.set_xlabel('Reg Res 2 hostcitytime2')
ax.set_ylabel('vals')
ax.plot(yneg2)
ax = figure.add_subplot(3, 2, 5)
ax.set_xlabel('Reg Res 3 hostcitytime')
ax.set_ylabel('vals')
ax.plot(ypos3)
ax = figure.add_subplot(3, 2, 6)
ax.set_xlabel('Reg Res 3 hostcitytime2')
ax.set_ylabel('vals')
ax.plot(yneg3)

# %%
from datetime import date
d0 = date(1978, 3, 1)
d1 = date(1978, 6, 1)
delta = d1 - d0
delta.days
# Out:
# 92

# %%
len(set(df3['time2'].dropna().values))
# Out:
# 117

# %%
p = df3.dropna(axis=0, subset=['hostcitytime', 'hostcitytime2'])
p[['hostcitytime', 'hostcitytime2']].loc[p['hostcitytime'] == 0.97]
# Out:
#         hostcitytime  hostcitytime2
# 11679           0.97         0.9409
# 33387           0.97         0.9409
# 48663           0.97         0.9409
# 83771           0.97         0.9409
# 119415          0.97         0.9409

# %%
import matplotlib.patches as patches

t = df3.dropna(axis=0, subset='time').groupby(by='time').mean()
fg = sns.lineplot(data=t, x='time', y='lnrepression', c='#000000')
rect1 = patches.Rectangle((0.92, 0), width=0.25, height=0.03, color='gray', alpha=0.2)
fg.axes.add_patch(rect1)
fg
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_40512\1173987235.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   t = df3.dropna(axis=0, subset='time').groupby(by='time').mean()
# <AxesSubplot: xlabel='time', ylabel='lnrepression'>

# %%
no_host_t = no_host.groupby(by='time').mean()
sns.lineplot(data=no_host_t, x='time', y='lnrepression', c='#000000')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_40512\1222694425.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   no_host_t = no_host.groupby(by='time').mean()
# <AxesSubplot: xlabel='time', ylabel='lnrepression'>

# %%
host_t = host.groupby(by='time').mean()
sns.lineplot(data=host_t, x='time', y='lnrepression', c='#000000')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_40512\1028522221.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   host_t = host.groupby(by='time').mean()
# <AxesSubplot: xlabel='time', ylabel='lnrepression'>

# %%
ax = sns.lineplot(data=no_host_t, x='time', y='lnrepression', c='#FF0000')
ax = sns.lineplot(data=host_t, x='time', y='lnrepression', c='#000000')
ax
# Out:
# <AxesSubplot: xlabel='time', ylabel='lnrepression'>

# %%
host
# Out:
#                       muni     id          prov  id_prov  \
# 11524   general pueyrredon   44.0  buenos aires      1.0
# 11525   general pueyrredon   44.0  buenos aires      1.0
# 11526   general pueyrredon   44.0  buenos aires      1.0
# 11527   general pueyrredon   44.0  buenos aires      1.0
# 11528   general pueyrredon   44.0  buenos aires      1.0
# ...                    ...    ...           ...      ...
# 119523             rosario  446.0      santa fe     21.0
# 119524             rosario  446.0      santa fe     21.0
# 119525             rosario  446.0      santa fe     21.0
# 119526             rosario  446.0      santa fe     21.0
# 119527             rosario  446.0      santa fe     21.0
#
#                                muniprov  repression  lnrepression  \
# 11524   general pueyrredon buenos aires         0.0      0.000000
# 11525   general pueyrredon buenos aires         1.0      0.693147
# 11526   general pueyrredon buenos aires         0.0      0.000000
# ...

# %%
no_host['lnrepression'].std()
# Out:
# 0.03838294441457273

# %%
import datetime

dates = pd.DataFrame({'Dates': pd.date_range(start='1978/3/1', end='1978/6/25').to_list() })
dates
# Out:
#          Dates
# 0   1978-03-01
# 1   1978-03-02
# 2   1978-03-03
# 3   1978-03-04
# 4   1978-03-05
# ..         ...
# 112 1978-06-21
# 113 1978-06-22
# 114 1978-06-23
# 115 1978-06-24
# 116 1978-06-25
#
# [117 rows x 1 columns]

# %%
host = host.groupby(by='time').mean()
host = host.reset_index()
host
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_40512\1692238280.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   host = host.groupby(by='time').mean()
#      time     id  id_prov  repression  lnrepression  dumrepression  hostcity  \
# 0    0.01  222.0      8.6         0.2      0.138629            0.2       1.0
# 1    0.02  222.0      8.6         0.2      0.138629            0.2       1.0
# 2    0.03  222.0      8.6         0.2      0.138629            0.2       1.0
# 3    0.04  222.0      8.6         0.2      0.138629            0.2       1.0
# 4    0.05  222.0      8.6         0.2      0.138629            0.2       1.0
# ..    ...    ...      ...         ...           ...            ...       ...
# 112  1.13  222.0      8.6         0.0      0.000000            0.0       1.0
# ...

# %%
hostd = pd.concat([host[['time', 'repression', 'lnrepression']], dates], axis=1)
hostd.loc[hostd.Dates.dt.month == 6]
# Out:
#      time  repression  lnrepression      Dates
# 92   0.93         0.6      0.358352 1978-06-01
# 93   0.94         0.4      0.219722 1978-06-02
# 94   0.95         0.0      0.000000 1978-06-03
# 95   0.96         0.2      0.138629 1978-06-04
# 96   0.97         0.4      0.219722 1978-06-05
# 97   0.98         0.4      0.277259 1978-06-06
# 98   0.99         0.0      0.000000 1978-06-07
# 99   1.00         0.2      0.138629 1978-06-08
# 100  1.01         0.2      0.138629 1978-06-09
# 101  1.02         0.0      0.000000 1978-06-10
# 102  1.03         0.0      0.000000 1978-06-11
# 103  1.04         0.0      0.000000 1978-06-12
# 104  1.05         0.0      0.000000 1978-06-13
# 105  1.06         0.0      0.000000 1978-06-14
# 106  1.07         0.0      0.000000 1978-06-15
# 107  1.08         0.0      0.000000 1978-06-16
# 108  1.09         0.0      0.000000 1978-06-17
# 109  1.10         0.0      0.000000 1978-06-18
# 110  1.11         0.0      0.000000 1978-06-19
# ...

# %%
hostd['eventx'] = np.where(hostd.Dates.dt.month == 6, hostd.Dates.dt.day, np.nan)
hostd['eventlow'] = np.where(hostd.eventx.isna(), 0, np.nan)
hostd['eventhigh'] = np.where(hostd.eventx.isna(), .51, np.nan)
hostd
# Out:
#      time  repression  lnrepression      Dates  eventx  eventlow  eventhigh
# 0    0.01         0.2      0.138629 1978-03-01     NaN       0.0       0.51
# 1    0.02         0.2      0.138629 1978-03-02     NaN       0.0       0.51
# 2    0.03         0.2      0.138629 1978-03-03     NaN       0.0       0.51
# 3    0.04         0.2      0.138629 1978-03-04     NaN       0.0       0.51
# 4    0.05         0.2      0.138629 1978-03-05     NaN       0.0       0.51
# ..    ...         ...           ...        ...     ...       ...        ...
# 112  1.13         0.0      0.000000 1978-06-21    21.0       NaN        NaN
# 113  1.14         0.0      0.000000 1978-06-22    22.0       NaN        NaN
# 114  1.15         0.0      0.000000 1978-06-23    23.0       NaN        NaN
# 115  1.16         0.0      0.000000 1978-06-24    24.0       NaN        NaN
# 116  1.17         0.2      0.138629 1978-06-25    25.0       NaN        NaN
#
# [117 rows x 7 columns]

# %%
from sklearn import preprocessing

o = hostd.loc[hostd['lnrepression'] != 0]
o['norm_repr'] = o['lnrepression'].apply(lambda x: (x - o['lnrepression'].min())/(o['lnrepression'].max() - o['lnrepression'].min()))
grouped_o = o.groupby(by=o.Dates.dt.month).mean()
grouped_o
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_40512\3617534288.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   o['norm_repr'] = o['lnrepression'].apply(lambda x: (x - o['lnrepression'].min())/(o['lnrepression'].max() - o['lnrepression'].min()))
# C:\Users\User\AppData\Local\Temp\ipykernel_40512\3617534288.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_o = o.groupby(by=o.Dates.dt.month).mean()
#            time  repression  lnrepression  eventx  eventlow  eventhigh  \
# Dates
# ...

# %%
o
# Out:
#      time  repression  lnrepression      Dates  eventx  eventlow  eventhigh  \
# 0    0.01         0.2      0.138629 1978-03-01     NaN       0.0       0.51
# 1    0.02         0.2      0.138629 1978-03-02     NaN       0.0       0.51
# 2    0.03         0.2      0.138629 1978-03-03     NaN       0.0       0.51
# 3    0.04         0.2      0.138629 1978-03-04     NaN       0.0       0.51
# 4    0.05         0.2      0.138629 1978-03-05     NaN       0.0       0.51
# 13   0.14         0.6      0.277259 1978-03-14     NaN       0.0       0.51
# 14   0.15         0.4      0.219722 1978-03-15     NaN       0.0       0.51
# 15   0.16         0.2      0.138629 1978-03-16     NaN       0.0       0.51
# 16   0.17         0.2      0.138629 1978-03-17     NaN       0.0       0.51
# 19   0.20         0.4      0.219722 1978-03-20     NaN       0.0       0.51
# 21   0.22         0.2      0.138629 1978-03-22     NaN       0.0       0.51
# ...

# %%
ys = grouped_o['norm_repr'].to_list()
ys.insert(0, 0)
ys.append(0)
xs = grouped_o['time'].to_list()
xs.insert(0, 0)
xs.append(1.17)
ax = sns.lineplot(x=xs, y=ys)
ax.set_xticks([0.01, 0.32, 0.62, 0.93, 1.17], labels=['March 1', 'April 1', 'May 1', 'June 1', 'June 25'])

# %%
ungrouped_host = df1.loc[df1['hostcity'] == 1.0]
ungrouped_host
# Out:
#                       muni     id          prov  id_prov  \
# 11583   general pueyrredon   44.0  buenos aires      1.0
# 11584   general pueyrredon   44.0  buenos aires      1.0
# 11585   general pueyrredon   44.0  buenos aires      1.0
# 11586   general pueyrredon   44.0  buenos aires      1.0
# 11587   general pueyrredon   44.0  buenos aires      1.0
# ...                    ...    ...           ...      ...
# 119431             rosario  446.0      santa fe     21.0
# 119432             rosario  446.0      santa fe     21.0
# 119433             rosario  446.0      santa fe     21.0
# 119434             rosario  446.0      santa fe     21.0
# 119435             rosario  446.0      santa fe     21.0
#
#                                muniprov  repression  lnrepression  \
# 11583   general pueyrredon buenos aires         0.0           0.0
# 11584   general pueyrredon buenos aires         0.0           0.0
# 11585   general pueyrredon buenos aires         0.0           0.0
# ...

# %%
model3 = smf.ols('lnrepression ~ hostcity + hostcitytime + hostcitytime2 + time + time2  + lnpop_1970 + vote_frejuli +\
                 literacy_avg + lnrebact1974 + lnrepression70_77+ zone2 + zone3 +\
            zone4 + zone5', data=df1).fit(cov_type='HC1')

model3.conf_int()
# Out:
#                           0         1
# Intercept         -0.008517  0.000707
# hostcity          -0.069939  0.061882
# hostcitytime       0.122896  0.679994
# hostcitytime2     -0.536401 -0.109812
# time              -0.007653  0.001560
# time2             -0.001404  0.005742
# lnpop_1970         0.002451  0.004073
# vote_frejuli      -0.000037  0.000058
# literacy_avg      -0.028007 -0.018244
# lnrebact1974      -0.001798 -0.000993
# lnrepression70_77  0.002413  0.003913
# zone2             -0.017698 -0.011647
# zone3             -0.014230 -0.009146
# zone4             -0.015538 -0.000795
# zone5             -0.011216 -0.007279

# %%
log_model1 = smf.logit('dumrepression ~ hostcitytime + hostcitytime2 + hostcity + time + time2', df1).fit(cov_type='HC1')

log_model2 = smf.logit('dumrepression ~ hostcitytime + hostcitytime2 + hostcity + time + time2 +\
            lnpop_1970 + vote_frejuli + literacy_avg + lnrebact1974 + lnrepression70_77', df1).fit(cov_type='HC1')

log_model3 = smf.logit('dumrepression ~ hostcitytime + hostcitytime2 + hostcity + time + time2 +\
            lnpop_1970 + vote_frejuli + literacy_avg + lnrebact1974 + lnrepression70_77 +\
            zone2 + zone3 + zone4 + zone5', df1).fit(cov_type='HC1')

ols_model1 = smf.ols('dumrepression ~ hostcitytime + hostcitytime2 + hostcity + time + time2', df1).fit(cov_type='HC1')

ols_model2 = smf.ols('dumrepression ~ hostcitytime + hostcitytime2 + hostcity + time + time2 +\
            lnpop_1970 + vote_frejuli + literacy_avg + lnrebact1974 + lnrepression70_77', df1).fit(cov_type='HC1')

ols_model3 = smf.ols('dumrepression ~ hostcitytime + hostcitytime2 + hostcity + time + time2 +\
            lnpop_1970 + vote_frejuli + literacy_avg + lnrebact1974 + lnrepression70_77 +\
            zone2 + zone3 + zone4 + zone5', df1).fit(cov_type='HC1')
# Out:
# Optimization terminated successfully.
#          Current function value: 0.019190
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.013826
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.013570
#          Iterations 13

# %%
ols_model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          dumrepression   R-squared:                       0.063
# Model:                            OLS   Adj. R-squared:                  0.063
# Method:                 Least Squares   F-statistic:                     14.45
# Date:                Mon, 05 Dec 2022   Prob (F-statistic):           2.15e-35
# Time:                        19:50:05   Log-Likelihood:                 81565.
# No. Observations:               56394   AIC:                        -1.631e+05
# Df Residuals:                   56379   BIC:                        -1.630e+05
# Df Model:                          14
# Covariance Type:                  HC1
# ...
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Q4: Robustness Check Using a Dichotomous Indicator of Repression
